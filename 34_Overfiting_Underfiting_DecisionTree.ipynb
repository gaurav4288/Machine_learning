# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav4288/Machine_learning/blob/main/34_Overfiting_Underfiting_DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

url = 'https://raw.githubusercontent.com/Muhammad-Sheraz-ds/100Days-of-Machine-Learning/main/Day%2063%20decision-trees-master/decision-trees-master/Social_Network_Ads.csv'

# %%
def analyzer(max_depth):
  data = pd.read_csv(url)
  X = data.iloc[:, 2:4].values
  y = data.iloc[:, -1].values

  clf = DecisionTreeClassifier(max_depth=max_depth)
  clf.fit(X, y)

  a = np.arange(start = X[:, 0].min() - 1, stop = X[:, 0].max() + 1, step = 0.1)
  b = np.arange(start = X[:, 1].min() - 1, stop = X[:, 1].max() + 1, step = 100)

  XX, YY = np.meshgrid(a, b)

  input_array = np.array([XX.ravel(), YY.ravel()]).T

  labels = clf.predict(input_array)

  plt.figure(figsize = (6,5))
  plt.contourf(XX, YY, labels.reshape(XX.shape), alpha = 0.5, cmap = 'rainbow')
  plt.scatter(X[:, 0], X[:, 1], c = y, s = 50, cmap = 'rainbow')
  plt.show()

# %%
analyzer(max_depth = None)

# %%
analyzer(max_depth = 4)

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2)

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 80,50

plot_tree(clf)
plt.show()
