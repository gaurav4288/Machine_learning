# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav4288/Machine_learning/blob/main/Multivariate_imputation_MICE_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>MICE stands for Multivariate Imputation by Chained Equations</h1>
# : MAR(missing at random)

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression

# %%
url = 'https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day40-iterative-imputer/50_Startups.csv'
df = np.round(pd.read_csv(url)[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)
df.to_csv('trai.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 0        17.0            14.0             47.0    19.0
# 1        16.0            15.0             44.0    19.0
# 2        15.0            10.0             41.0    19.0
# 3        14.0            12.0             38.0    18.0
# 4        14.0             9.0             37.0    17.0
# 5        13.0            10.0             36.0    16.0
# 6        13.0            15.0             13.0    16.0
# 7        13.0            15.0             32.0    16.0
# 8        12.0            15.0             31.0    15.0
# 9        12.0            11.0             30.0    15.0
# 10       10.0            11.0             23.0    15.0
# 11       10.0             9.0             25.0    14.0
# 12        9.0            13.0             25.0    14.0
# 13        9.0            14.0             25.0    13.0
# 14       12.0            16.0             26.0    13.0
# 15       11.0            12.0             26.0    13.0
# ...

# %%
df = df.iloc[:,0:-1]

# %%
df.iloc[1,0] = np.NaN
df.iloc[3,1] = np.NaN
df.iloc[-1,-1] = np.NaN
# Out:
# <ipython-input-123-9e8f6afe97a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[1,0] = np.NaN
# <ipython-input-123-9e8f6afe97a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[3,1] = np.NaN
# <ipython-input-123-9e8f6afe97a9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[-1,-1] = np.NaN

# %%
df0 = pd.DataFrame()

df0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

# %%
# 0th Iteration
df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   17.000000       14.000000        47.000000
# 1    7.163265       15.000000        44.000000
# 2   15.000000       10.000000        41.000000
# 3   14.000000       12.163265        38.000000
# 4   14.000000        9.000000        37.000000
# 5   13.000000       10.000000        36.000000
# 6   13.000000       15.000000        13.000000
# 7   13.000000       15.000000        32.000000
# 8   12.000000       15.000000        31.000000
# 9   12.000000       11.000000        30.000000
# 10  10.000000       11.000000        23.000000
# 11  10.000000        9.000000        25.000000
# 12   9.000000       13.000000        25.000000
# 13   9.000000       14.000000        25.000000
# 14  12.000000       16.000000        26.000000
# 15  11.000000       12.000000        26.000000
# 16   8.000000       12.000000        26.000000
# 17   9.000000       15.000000        28.000000
# 18   9.000000       11.000000        29.000000
# ...

# %%
# Remove the col1 imputed value
df1 = df0.copy()

df1.iloc[1,0] = np.NaN

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0        17.0       14.000000        47.000000
# 1         NaN       15.000000        44.000000
# 2        15.0       10.000000        41.000000
# 3        14.0       12.163265        38.000000
# 4        14.0        9.000000        37.000000
# 5        13.0       10.000000        36.000000
# 6        13.0       15.000000        13.000000
# 7        13.0       15.000000        32.000000
# 8        12.0       15.000000        31.000000
# 9        12.0       11.000000        30.000000
# 10       10.0       11.000000        23.000000
# 11       10.0        9.000000        25.000000
# 12        9.0       13.000000        25.000000
# 13        9.0       14.000000        25.000000
# 14       12.0       16.000000        26.000000
# 15       11.0       12.000000        26.000000
# 16        8.0       12.000000        26.000000
# 17        9.0       15.000000        28.000000
# 18        9.0       11.000000        29.000000
# ...

# %%
# Use first 3 rows to build a model and use the last for prediction

X = df1.iloc[[0,2,3,4],1:3]
X
# Out:
#    Administration  Marketing Spend
# 0       14.000000             47.0
# 2       10.000000             41.0
# 3       12.163265             38.0
# 4        9.000000             37.0

# %%
y = df1.iloc[[0,2,3,4],0]
y
# Out:
# 0    17.0
# 2    15.0
# 3    14.0
# 4    14.0
# Name: R&D Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.90294324])

# %%
df1.iloc[1,0] = 23.14

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0       17.00       14.000000        47.000000
# 1       23.14       15.000000        44.000000
# 2       15.00       10.000000        41.000000
# 3       14.00       12.163265        38.000000
# 4       14.00        9.000000        37.000000
# 5       13.00       10.000000        36.000000
# 6       13.00       15.000000        13.000000
# 7       13.00       15.000000        32.000000
# 8       12.00       15.000000        31.000000
# 9       12.00       11.000000        30.000000
# 10      10.00       11.000000        23.000000
# 11      10.00        9.000000        25.000000
# 12       9.00       13.000000        25.000000
# 13       9.00       14.000000        25.000000
# 14      12.00       16.000000        26.000000
# 15      11.00       12.000000        26.000000
# 16       8.00       12.000000        26.000000
# 17       9.00       15.000000        28.000000
# 18       9.00       11.000000        29.000000
# ...

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

df = np.round(pd.read_csv(url)[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)
df = df.iloc[:,0:-1]
df.iloc[1,0] = np.NaN
df.iloc[3,1] = np.NaN
df.iloc[-1,-1] = np.NaN
print(df)

imp = IterativeImputer(max_iter=1, random_state=0)
imp.fit(df)
# Transform the dataframe
imputed_df = imp.transform(df)
imputed_df = pd.DataFrame(imputed_df, columns=df.columns)
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0        17.0            14.0             47.0
# 1         NaN            15.0             44.0
# 2        15.0            10.0             41.0
# 3        14.0             NaN             38.0
# 4        14.0             9.0             37.0
# 5        13.0            10.0             36.0
# 6        13.0            15.0             13.0
# 7        13.0            15.0             32.0
# 8        12.0            15.0             31.0
# 9        12.0            11.0             30.0
# 10       10.0            11.0             23.0
# 11       10.0             9.0             25.0
# 12        9.0            13.0             25.0
# 13        9.0            14.0             25.0
# 14       12.0            16.0             26.0
# 15       11.0            12.0             26.0
# 16        8.0            12.0             26.0
# 17        9.0            15.0             28.0
# 18        9.0            11.0             29.0
# ...

# %%
imputed_df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   17.000000        14.00000        47.000000
# 1   13.959654        15.00000        44.000000
# 2   15.000000        10.00000        41.000000
# 3   14.000000        12.63411        38.000000
# 4   14.000000         9.00000        37.000000
# 5   13.000000        10.00000        36.000000
# 6   13.000000        15.00000        13.000000
# 7   13.000000        15.00000        32.000000
# 8   12.000000        15.00000        31.000000
# 9   12.000000        11.00000        30.000000
# 10  10.000000        11.00000        23.000000
# 11  10.000000         9.00000        25.000000
# 12   9.000000        13.00000        25.000000
# 13   9.000000        14.00000        25.000000
# 14  12.000000        16.00000        26.000000
# 15  11.000000        12.00000        26.000000
# 16   8.000000        12.00000        26.000000
# 17   9.000000        15.00000        28.000000
# 18   9.000000        11.00000        29.000000
# ...
